# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# /home/oleg/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
dfX = pd.read_csv("datas/dataX_eyler.csv", sep=";")
dfX
# Out:
#             t              x
# 0        0.00   0.000000e+00
# 1        0.01   1.000000e-01
# 2        0.02   2.000000e-01
# 3        0.03   2.990000e-01
# 4        0.04   3.960000e-01
# ...       ...            ...
# 99995  999.95  1.078770e+216
# 99996  999.96  1.116420e+216
# 99997  999.97  1.143280e+216
# 99998  999.98  1.158970e+216
# 99999  999.99  1.163240e+216
#
# [100000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfX, x='t', y=' x')
xx = dfX['t'].to_numpy()
yy = np.sin(xx*10+np.pi/2)
sns.scatterplot(x = xx, y=yy)
# Out:
# <Axes: xlabel='t', ylabel=' x'>

# %%
dfV = pd.read_csv("datas/dataV_eyler.csv", sep=";")
dfV
# Out:
#             t              x
# 0        0.00   1.000000e+01
# 1        0.01   1.000000e+01
# 2        0.02   9.900000e+00
# 3        0.03   9.700000e+00
# 4        0.04   9.401000e+00
# ...       ...            ...
# 99995  999.95  3.764940e+216
# 99996  999.96  2.686180e+216
# 99997  999.97  1.569760e+216
# 99998  999.98  4.264830e+215
# 99999  999.99 -7.324920e+215
#
# [100000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfV, x='t', y=' x')
xx = dfV['t'].to_numpy()
yy = np.sin(xx*10)*(-10)
sns.scatterplot(x = xx, y=yy)
# Out:
# <Axes: xlabel='t', ylabel=' x'>

# %%
dfX_h = pd.read_csv("datas/dataX_hoin.csv", sep=";")
dfX_h
# Out:
#             t         x
# 0        0.00  0.000000
# 1        0.01  0.100000
# 2        0.02  0.199000
# 3        0.03  0.296007
# 4        0.04  0.390050
# ...       ...       ...
# 99995  999.95  2.296780
# 99996  999.96  2.548080
# 99997  999.97  2.773830
# 99998  999.98  2.971790
# 99999  999.99  3.139960
#
# [100000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfX_h, x='t', y=' x')
xx = dfX_h['t'].to_numpy()
yy = np.sin(xx*10+np.pi/2)
sns.scatterplot(x = xx, y=yy)
# Out:
# <Axes: xlabel='t', ylabel=' x'>

# %%
dfV_h = pd.read_csv("datas/dataV_hoin.csv", sep=";")
dfV_h
# Out:
#             t         x
# 0        0.00  10.00000
# 1        0.01   9.95000
# 2        0.02   9.80025
# 3        0.03   9.55225
# 4        0.04   9.20848
# ...       ...       ...
# 99995  999.95  26.27810
# 99996  999.96  23.85000
# 99997  999.97  21.18260
# 99998  999.98  18.30290
# 99999  999.99  15.23960
#
# [100000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfV_h, x='t', y=' x')
xx = dfV_h['t'].to_numpy()
yy = np.sin(xx*10)*(-10)
# sns.scatterplot(x = xx, y=yy)

# %%
dfX_R = pd.read_csv("datas/dataX_RK4.csv", sep=";")
dfX_R
# Out:
#             t          x
# 0        0.00   0.000000
# 1        0.01   4.991670
# 2        0.02   9.933460
# 3        0.03  14.776000
# 4        0.04  19.470900
# ...       ...        ...
# 99995  999.95   9.814880
# 99996  999.96   4.874830
# 99997  999.97  -0.113935
# 99998  999.98  -5.101560
# 99999  999.99 -10.038200
#
# [100000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfX_R, x='t', y=' x')
xx = dfX_R['t'].to_numpy()
yy = np.sin(xx*10+np.pi/2)
# sns.scatterplot(x = xx, y=yy)

# %%
dfV_R = pd.read_csv("datas/dataV_RK4.csv", sep=";")
dfV_R
# Out:
#               t         x
# 0          0.00     0.000
# 1          0.01  -998.333
# 2          0.02 -1986.690
# 3          0.03 -2955.200
# 4          0.04 -3894.180
# ...         ...       ...
# 999995  9999.95 -5760.410
# 999996  9999.96 -4924.030
# 999997  9999.97 -4038.450
# 999998  9999.98 -3112.520
# 999999  9999.99 -2155.490
#
# [1000000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfV_R, x='t', y=' x')
xx = dfV_R['t'].to_numpy()
yy = np.sin(xx*10)*(-10)
sns.scatterplot(x = xx, y=yy)
# Out:
# <Axes: xlabel='t', ylabel=' x'>
