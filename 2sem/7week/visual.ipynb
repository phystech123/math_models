# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math
import os

# %%
dfX1 = pd.read_csv("data/0.csv")[:10000:50]
dfX2 = pd.read_csv("data/1.csv")[:10000:50]
dfX3 = pd.read_csv("data/2.csv")[:10000:50]

plt.figure()
sns.scatterplot(data=dfX1, x='i', y='x', alpha=1, s=300, color="r")
sns.scatterplot(data=dfX2, x='i', y='x', alpha=1, s=300, color="g")
sns.scatterplot(data=dfX3, x='i', y='x', alpha=1, s=300, color="b")
# Out:
# <Axes: xlabel='i', ylabel='x'>

# %% [markdown]
# ct*e(-wt)` = c*e() + ct*e()*-w = (c-wct)e()
# c*e(-g - sqrt(g**2 - w**2)t) ...(0) = c*2*(-sqrt(g**2 - w**2))=10 => c=1/(2sqrt(3))
