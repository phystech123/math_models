# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math
import os

# %%
# dfX1 = pd.read_csv("data/0.csv")[:100000:1]
# dfX2 = pd.read_csv("data/1.csv")[:100000:1]
# dfX3 = pd.read_csv("data/2.csv")[:100000:1]

# plt.figure()
# sns.scatterplot(data=dfX1, x='i', y='x', alpha=1, s=50, color="r")
# sns.scatterplot(data=dfX2, x='i', y='x', alpha=1, s=50, color="g")
# sns.scatterplot(data=dfX3, x='i', y='x', alpha=1, s=50, color="b")


plt.figure()
for i in range(20):
    sns.scatterplot(data=pd.read_csv(f"data_res/{i}.csv")[9800:9900:1], x='i', y='x', alpha=1, s=50)

# %%
dx0 = pd.read_csv(f"data/0.csv")
dx1 = pd.read_csv(f"data/1.csv")
dx2 = pd.read_csv(f"data/2.csv")
dx3 = pd.read_csv(f"data/3.csv")
# dx4 = pd.read_csv(f"data/4.csv")
# dx5 = pd.read_csv(f"data/5.csv")
# dx6 = pd.read_csv(f"data/6.csv")
# dx7 = pd.read_csv(f"data/7.csv")
# dx8 = pd.read_csv(f"data/8.csv")
# dx9 = pd.read_csv(f"data/9.csv")

W=[0 for i in range(10000)]
P=[0 for i in range(10000)]
for i in range(10000):
#     W[i] += pow(dx0["v"][i], 2)*dx0["m"][0] + pow(dx1["v"][i], 2)*dx1["m"][0] + pow(dx2["v"][i], 2)*dx2["m"][0] + pow(dx3["v"][i], 2)*dx3["m"][0] + pow(dx4["v"][i], 2)*dx4["m"][0] + pow(dx5["v"][i], 2)*dx5["m"][0] + pow(dx6["v"][i], 2)*dx6["m"][0] + pow(dx7["v"][i], 2)*dx7["m"][0] + pow(dx8["v"][i], 2)*dx8["m"][0] + pow(dx9["v"][i], 2)*dx9["m"][0]
    W[i] += pow(dx0["v"][i], 2)*dx0["m"][0] + pow(dx1["v"][i], 2)*dx1["m"][0] + pow(dx2["v"][i], 2)*dx2["m"][0] + pow(dx3["v"][i], 2)*dx3["m"][0]
    W[i] += pow(dx0["v"][i], 2)*dx0["m"][0] + pow(dx1["v"][i], 2)*dx1["m"][0] + pow(dx2["v"][i], 2)*dx2["m"][0] + pow(dx3["v"][i], 2)*dx3["m"][0]
plt.scatter(dx0["i"].to_list(), W)
print(W)

# <E>=nkT
# Out:
# [np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(
# ...

# %%
dx0 = pd.read_csv(f"data/0.csv")

W=[0 for i in range(100000)]
P=[0 for i in range(100000)]

for j in range(20):
    dx = pd.read_csv(f"data/{j}.csv")
    for i in range(100000):
        W[i] += pow(dx["v"][i], 2)*dx["m"][0]
        P[i] += dx["v"][i] * dx["m"][0]

plt.figure()
plt.scatter(dx0["i"].to_list(), W)
plt.figure()
# plt.scatter(dx0["i"].to_list(), P)
# print(W)

# <E>=nkT

# %%
dx = pd.read_csv("data/col.csv")
x=dx["i"][:1000]
y=dx["n"][:1000]
xx = [0 for i in range(len(x))]
yy = [0 for i in range(len(y))]

xx[0]=x[0]
yy[0]=y[0]

for i in range(1, len(x)):
    xx[i] = xx[i-1] + x[i]
    yy[i] = yy[i-1] + y[i]

plt.figure()
# sns.scatterplot(x=x, y=y)
sns.scatterplot(x=xx, y=yy)
# Out:
# <Axes: >

# %%
dx0 = pd.read_csv(f"data/0.csv")
# # энергия каждого шарика в отдельности 
# W=[[0 for j in range(10000)] for i in range(20)]
# for j in range(20):
#     dx = pd.read_csv(f"data/{j}.csv")
#     for i in range(10000):
#         W[j][i] = pow(dx["v"][i], 2)*dx["m"][0]
# plt.figure()

# попытка термолизации - средняя энергия вида шариков
len1 = len2 = 0
b=10

W0=[[0 for j in range(100000)] for i in range(2)]
for j in range(20):
    dx = pd.read_csv(f"data/{j}.csv")
    for i in range(100000):
        W0[int(dx["m"][0]==25)][i] += pow(dx["v"][i], 2)*dx["m"][0]
    if(dx["m"][0]==1):
        len1+=1
    else:
        len2+=1



W1=[[0 for j in range(b)] for i in range(2)]
for i in range(b):
    for j in range(int(100000/b)):
        W1[0][i]+=W0[0][i*int(100000/b) + j]
        W1[1][i]+=W0[1][i*int(100000/b) + j]
    W1[0][i]/=len1
    W1[1][i]/=len2


plt.figure()
for i in range(2):
    sns.scatterplot(x=dx0["i"][::int(100000/b)], y=W1[i][::])

# %%
print(W1)
print('\n')
print(len1)
print(len2)
for i in range(20):
    dx = pd.read_csv(f"data/{i}.csv")
    print(dx["v"][100000-1], dx["m"][100000-1], dx["v"][100000-1]*dx["v"][100000-1]*dx["m"][100000-1])
# Out:
# [[np.float64(52986.951888912714), np.float64(66.13978748709773), np.float64(66.13978748709773), np.float64(66.13978748709773), np.float64(66.13978748709773), np.float64(66.13978748709773), np.float64(66.13978748709773), np.float64(66.13978748709773), np.float64(66.13978748709773), np.float64(66.13978748709773)], [np.float64(72729.09545698577), np.float64(2993.888481455498), np.float64(2993.888481455498), np.float64(2993.888481455498), np.float64(2993.888481455498), np.float64(2993.888481455498), np.float64(2993.888481455498), np.float64(2993.888481455498), np.float64(2993.888481455498), np.float64(2993.888481455498)]]
#
#
# 6
# 14
# 0.00126736080331 25 4.015508514416421e-05
# 0.00102084871471 25 2.605330245812647e-05
# 0.00339249654105 25 0.0002877258195259054
# 0.00288249529762 25 0.00020771947852003532
# 0.002538183105 25 0.000161059336862686
# 0.010180286236 1 0.00010363822784689104
# 0.0132160828439 1 0.00017466484573682792
# 0.015764840246 1 0.0002485301879819014
# ...

# %%
plt.figure()
for i in range(2):
    sns.scatterplot(x=dx0["i"][::100], y=W0[i][::100])
