# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math
import os
import json

# %%
dir_ = "./configs"
file_ = "main.json"

os.system(f'./build/main {dir_}/{file_}')

with open(dir_+"/"+file_, 'r') as file:
    data = json.load(file)

# %%
# dx = pd.read_csv("data/1.csv", sep=' ', )
with open("data/1.csv") as file:
    dx = np.loadtxt(file, delimiter=" ")
plt.pcolor(dx[1:-1, 1:-1])
