# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
with open("data.txt") as file:
    a = file.readlines()
    x = [i.split(", ")[0] for i in a]
    y = [float(i.split(", ")[1].split("\n")[0]) for i in a]
    sns.barplot(x=x, y=y)
