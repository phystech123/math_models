# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dfX = pd.read_csv("dataX_eyler.csv", sep=";")
dfX
# Out:
#          t         x
# 0    0.000  1.000000
# 1    0.001  1.000000
# 2    0.002  0.999900
# 3    0.003  0.999700
# 4    0.004  0.999400
# ..     ...       ...
# 995  0.995 -0.909519
# 996  0.996 -0.904253
# 997  0.997 -0.898895
# 998  0.998 -0.893446
# 999  0.999 -0.887908
#
# [1000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfX, x='t', y=' x')
xx = dfX['t'].to_numpy()
yy = np.sin(xx*10+np.pi/2)
sns.scatterplot(x = xx, y=yy)
# Out:
# <Axes: xlabel='t', ylabel=' x'>

# %%
dfV = pd.read_csv("dataV_eyler.csv", sep=";")
dfV
# Out:
#          t        x
# 0    0.000  0.00000
# 1    0.001 -0.10000
# 2    0.002 -0.20000
# 3    0.003 -0.29999
# 4    0.004 -0.39996
# ..     ...      ...
# 995  0.995  5.26679
# 996  0.996  5.35774
# 997  0.997  5.44816
# 998  0.998  5.53806
# 999  0.999  5.62740
#
# [1000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfV, x='t', y=' x')
xx = dfV['t'].to_numpy()
yy = np.sin(xx*10)*(-10)
sns.scatterplot(x = xx, y=yy)
# Out:
# <Axes: xlabel='t', ylabel=' x'>

# %%
dfX_h = pd.read_csv("dataX_hoin.csv", sep=";")
dfX_h
# Out:
#             t         x
# 0       0.000  1.000000
# 1       0.001  0.999950
# 2       0.002  0.999800
# 3       0.003  0.999550
# 4       0.004  0.999200
# ...       ...       ...
# 99995  99.995  0.589680
# 99996  99.996  0.581577
# 99997  99.997  0.573416
# 99998  99.998  0.565198
# 99999  99.999  0.556923
#
# [100000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfX_h, x='t', y=' x')
xx = dfX_h['t'].to_numpy()
yy = np.sin(xx*10+np.pi/2)
# sns.scatterplot(x = xx, y=yy)

# %%
dfV_h = pd.read_csv("dataV_hoin.csv", sep=";")
dfV_h
# Out:
#              t             x
# 0         0.00  0.000000e+00
# 1         0.02 -2.000000e+00
# 2         0.04 -3.920000e+00
# 3         0.06 -5.682400e+00
# 4         0.08 -7.215940e+00
# ...        ...           ...
# 99995  1999.90  2.806250e+09
# 99996  1999.92  1.963190e+09
# 99997  1999.94  1.046190e+09
# 99998  1999.96  8.099410e+07
# 99999  1999.98 -8.878710e+08
#
# [100000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfV_h, x='t', y=' x')
xx = dfV_h['t'].to_numpy()
yy = np.sin(xx*10)*(-10)
# sns.scatterplot(x = xx, y=yy)

# %%
dfX_R = pd.read_csv("dataX_RK4.csv", sep=";")
dfX_R
# Out:
#             t          x
# 0        0.00          1
# 1        0.01          1
# 2        0.02   0.993719
# 3        0.03   0.981156
# 4        0.04   0.962351
# ...       ...        ...
# 99995  999.95       -nan
# 99996  999.96       -nan
# 99997  999.97       -nan
# 99998  999.98       -nan
# 99999  999.99       -nan
#
# [100000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfX_R, x='t', y=' x')
xx = dfX_R['t'].to_numpy()
yy = np.sin(xx*10+np.pi/2)
# sns.scatterplot(x = xx, y=yy)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[156], line 2
#       1 plt.figure()
# ----> 2 sns.scatterplot(data=dfX_R, x='t', y=' x')
#       3 xx = dfX_R['t'].to_numpy()
#       4 yy = np.sin(xx*10+np.pi/2)
#
# File ~/.local/lib/python3.10/site-packages/seaborn/relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File ~/.local/lib/python3.10/site-packages/seaborn/relational.py:461, in _ScatterPlotter.plot(self, ax, kws)
#     458     kws["linewidth"] = linewidth
#     460 # Finalize the axes details
# --> 461 self._add_axis_labels(ax)
#     462 if self.legend:
# ...

# %%
dfV_R = pd.read_csv("dataV_RK4.csv", sep=";")
dfV_R
# Out:
#             t         x
# 0        0.00   0.00000
# 1        0.01  -1.00000
# 2        0.02  -1.99000
# 3        0.03  -2.96007
# 4        0.04  -3.90050
# ...       ...       ...
# 99995  999.95 -22.97560
# 99996  999.96 -25.49030
# 99997  999.97 -27.73600
# 99998  999.98 -29.71780
# 99999  999.99 -31.40120
#
# [100000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=dfV_R, x='t', y=' x')
xx = dfV_R['t'].to_numpy()
yy = np.sin(xx*10)*(-10)
# sns.scatterplot(x = xx, y=yy)
